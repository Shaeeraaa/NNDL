# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaeeraaa/NNDL/blob/main/feed_forward_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x=np.array([[0.5,0.1,0.7]])
y=np.array([[0.6]])

model=Sequential([
    Dense(2,activation='sigmoid',input_shape=(3,)),
    Dense(1,activation='sigmoid')
])

model.compile(loss='mse',optimizer='sgd')

model.fit(x,y,epochs=1000,verbose=0)

output=model.predict(x)
print("output",output)
